# %%
import pandas as pd
import numpy as np
import math

#Read data from SAP file 
#file_sfdc = "C:\Users\Bedantika\Documents\Python Training\test_sfdc"
#dfsap = pd.read_csv(r"C:\Users\Bedantika\Documents\Python Training\test_sap.csv")
#dfsap = pd.read_csv(r"C:\Users\Bedantika\Recon\sap_output2019_07_10.csv")
dfsap = pd.read_csv(r"C:\Users\Bedantika\Recon\sap_output2019_07_15.csv")

#Read data from SFDC file 
#print(dfsap)
#dfsfdc = pd.read_csv(r"C:\Users\Bedantika\Documents\Python Training\test_sfdc.csv")
#dfsfdc = pd.read_csv(r"C:\Users\Bedantika\Recon\sfdc_output2019_07_10.csv")
dfsfdc = pd.read_csv(r"C:\Users\Bedantika\PycharmProjects\SOQL_datadump\datafile\Quote.csv")
#dfsfdc["QUOTE_ID"].dfsfdc.replace(['',1])                   
                     
print(dfsfdc)
print("****")

#Joining data from 2 files with 'Name' as key 
common = pd.merge(dfsap,dfsfdc,on = 'QUOTE_ID',how = 'outer',indicator = True)

print(common)
common = common.replace(np.nan, 0)

print("****")
print("****")

# Listing the columns of a file 
l = list(dfsap.columns)

#Removing the primary key from the list to be comapred between files 
l.remove('QUOTE_ID')   
print(l)

def check(row):

     mismatch_flg = 0 

# Records are present only in the SAP file 
     if  row['_merge'] == 'left_only' :
          return 'SAP_Only'
        
# Records are present only in the SFDC file         
     elif row['_merge'] == 'right_only' :
         return 'SFDC_Only'
                
# Records are present in both files and hence being compared fieldwise
     elif row['_merge'] == 'both' :
        
            s = "Data match"
            
# Create the column names dynamically and compare their values             
            for column in l:

                colx = column + '_x'
                coly = column + '_y'  
                
                if row[colx] != '' or row[coly]!= '':
                   
                    if row[colx] != row[coly] :

                        if mismatch_flg == 0 :
                            mismatch_flg = 1 
                            s = "Data Mismatch"

                        s = s  + column + ','
                        
               

            if s != "":
                return s 

        
# Apply 'check' fundtion for each record and put compare result in comment field
# comment field will have SAP_only for records present only in SAP file 
# SFDC_only for records only in SFDC file and field indicators for mismatch for records in both files

for  row in common.itertuples(): 
        common['comment'] = common.apply(lambda row : check(row), axis = 1) 

# Removing the '_merge' column from display 
common.drop('_merge', axis=1, inplace=True)

#Saving the merged data to a file 
common.to_csv('recon_output.csv')

print(common)
# Out:
#          QUOTE_ID                             QUOTE_DESC QUOTE_TYPE  \
# 0      0005330691                                   Test        ZQR
# 1      0005371158                             27_JUNE_01        ZQR
# 2      0005371159                             27_JUNE_02        ZQR
# 3      0005371095                           Name 5777901        ZQR
# 4      0005371162                             28_JUNE_01        ZQR
# 5   quote test 99                                    ZQR       OM02
# 6      0005371163                             28_JUNE_02        ZQR
# 7      0005371160                                     tr        ZQR
# 8      0005371164              Test Quote for Approval 1        ZQR
# 9      0005371157                                test625        ZQR
# 10     0005370554                       Germany Quote v2        ZQR
# 11     0005371165                      Test Quote Q387-1        ZQR
# 12     0005371161                             27_June_03        ZQR
# 13     0005371166                       quote-SF-BUG-340        ZQR
# 14     0005371168                       Test Quote Q2001        ZQR
# 15     0005371169                Test Quote 02 July 2019        ZQR
# 16     0005371170                             Test Q3001        ZQR
# 17     0005371167   Test Quote for SF-BUG-340 Before Fix        ZQR
# 18     0005371171                   Test Quote to add QL        ZQR
# 19     0005371172                         Test Quote QL2        ZQR
# 20     0005371173       Test Quote Before fix for 393 QL        ZQR
# 21     0005371175                                     T2        ZQR
# 22     0005371176                                  T " Q        ZQR
# 23     0005371076                                test q1        ZQR
# 24     0005371177       Test Quote for Quote Lines error        ZQR
# 25     0005371156  Test Quote for SF-BUG-393 for testing        ZQR
# 26     0005370825                        test quote 2500        ZQR
# 27     0005371145     Test Quote with special Characters        ZQR
# 28     0005371178                    "Test quote 050719"        ZQR
# 29     0005371154                                test617        ZQR
# 30     0005371174                                     T1        ZQR
# 31     0005371179                 Test Quote for Booking        ZQR
# 32     0005371180                        Test Quote T100        ZQR
# 33     0005370823       TQ 0904 first time print check 1        ZQR
# 34     0005371183                       test non primary        ZQR
# 35     0005371184                                 test1q        ZQR
# 36     0005370505                    New Quote 1-10-19 A        ZQR
# 37     0005370795                       test large quote        ZQR
# 38     0005371187                               test t23        ZQR
# 39     0005370603                               Purchase        ZQR
# 40     0005371188              Test Quote SF-BUG-387 T-1        ZQR
# 41     0005371189                   Quote-For-SF-BUG-340        ZQR
# 42     0005371057                                   cad1        ZQR
# 43     0005371191                                    tt2        ZQR
# 44     0005371192                                Testing        ZQR
# 45     0005371195                           Test 13 JULY        ZQR
# 46     0005371196                        Test 13 July 01        ZQR
# 47     0005371197                              test fsdf        ZQR
# 48     0005330594                              testing 3        ZQR
# 49     0005370771                       test quote small        ZQR
# 50     0005370817                      Test Quote 1000 5        ZQR
#
#    SALES_ORG_DESC              STATUS     ZZSFDC_QUOTE_ID
# 0            OM01               E0001  0Q01k0000004cgqCAA
# 1            OM01               E0001  0Q01k000000NPMcCAO
# 2            OM01               E0004  0Q01k000000NPMhCAO
# 3            OM01               E0009  0Q01k0000004zgdCAA
# 4            OM01               E0009  0Q01k000000NPNpCAO
# 5           E0004  0Q01k0000004mCQCAY                 NaN
# 6            OM01               E0004  0Q01k000000NPNuCAO
# 7            OM02               E0004  0Q01k000000NPMwCAO
# 8            OM02               E0004  0Q01k000000NPOdCAO
# 9            OM01               E0001  0Q01k000000NPKRCA4
# 10           OM01               E0001  0Q01k0000004jhaCAA
# 11           OM02               E0004  0Q01k000000NPOiCAO
# 12           OM01               E0009  0Q01k000000NPN1CAO
# 13           OM02               E0001  0Q01k000000NPRwCAO
# 14           OM02               E0001  0Q01k000000NPS6CAO
# 15           OM02               E0001  0Q01k000000NPSBCA4
# 16           OM02               E0001  0Q01k000000NPSGCA4
# 17           OM02               E0004  0Q01k000000NPS1CAO
# 18           OM01               E0001  0Q01k000000NPUlCAO
# 19           OM01               E0001  0Q01k000000NPVFCA4
# 20           OM01               E0001  0Q01k000000NPVUCA4
# 21           OM01               E0001  0Q01k000000NPW8CAO
# 22           OM01               E0001  0Q01k000000NPWICA4
# 23           OM02               E0009  0Q01k0000004zDMCAY
# 24           OM01               E0001  0Q01k000000NPXfCAO
# 25           OM01               E0001  0Q01k000000NPIVCA4
# 26           OM01               E0001  0Q01k0000004meeCAA
# 27           OM02               E0001  0Q01k000000NOpsCAG
# 28           OM01               E0001  0Q01k000000NPYTCA4
# 29           OM01               E0001  0Q01k000000NOuTCAW
# 30           OM01               E0004  0Q01k000000NPVeCAO
# 31           OM01               E0013  0Q01k000000NPa5CAG
# 32           OM01               E0001  0Q01k000000NPaACAW
# 33           OM01               E0001  0Q01k0000004mcOCAQ
# 34           OM01               E0001  0Q01k000000NPb8CAG
# 35           OM02               E0001  0Q01k000000NPbhCAG
# 36           OM01               E0009  0Q01k0000004j8FCAQ
# 37           OM01               E0013  0Q01k0000004mLICAY
# 38           OM02               E0001  0Q01k000000NPevCAG
# 39           OM01               E0009  0Q01k0000000aM7CAI
# 40           OM02               E0001  0Q01k000000NPf0CAG
# 41           OM02               E0018  0Q01k000000NPfACAW
# 42           OM01               E0004  0Q01k0000004yrBCAQ
# 43           OM02               E0004  0Q01k000000NPfKCAW
# 44           OM02               E0001  0Q01k000000NPfZCAW
# 45           OM02               E0001  0Q01k000000NPfoCAG
# 46           OM02               E0001  0Q01k000000NPftCAG
# 47           OM01               E0001  0Q01k000000NPg3CAG
# 48           OM01               E0001  0Q01k0000004aH5CAI
# 49           OM02               E0001  0Q01k0000004mC6CAI
# 50           OM01               E0007  0Q01k0000004mZKCAY
# ****
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-f16389d5c3a0> in <module>
#      20
#      21 #Joining data from 2 files with 'Name' as key
# ---> 22 common = pd.merge(dfsap,dfsfdc,on = 'QUOTE_ID',how = 'outer',indicator = True)
#      23
#      24 print(common)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     531         # validate the merge keys dtypes. We may need to coerce
#     532         # to avoid incompat dtypes
# --> 533         self._maybe_coerce_merge_keys()
#     534
#     535         # If argument passed to validate,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#     978                       (inferred_right in string_types and
#     979                        inferred_left not in string_types)):
# --> 980                     raise ValueError(msg)
#     981
#     982             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat
